# %% [markdown]
# <a href="https://colab.research.google.com/github/aniget/SoftUni-AI-Integrations-for-developers/blob/main/Vector%20Databases%2C%20Embeddings%20and%20RAG/Embeddings_compare_using_VoyageAI_API.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q anthropic numpy
# !pip install -U voyageai
# Out:
# Collecting voyageai
#   Downloading voyageai-0.3.7-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.12/dist-packages (from voyageai) (3.13.3)
# Collecting aiolimiter (from voyageai)
#   Downloading aiolimiter-1.2.1-py3-none-any.whl.metadata (4.5 kB)
# Collecting ffmpeg-python (from voyageai)
#   Downloading ffmpeg_python-0.2.0-py3-none-any.whl.metadata (1.7 kB)
# Collecting langchain-text-splitters>=0.3.8 (from voyageai)
#   Downloading langchain_text_splitters-1.1.1-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from voyageai) (2.0.2)
# Requirement already satisfied: pillow in /usr/local/lib/python3.12/dist-packages (from voyageai) (11.3.0)
# Requirement already satisfied: pydantic>=1.10.8 in /usr/local/lib/python3.12/dist-packages (from voyageai) (2.12.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from voyageai) (2.32.4)
# Requirement already satisfied: tenacity in /usr/local/lib/python3.12/dist-packages (from voyageai) (9.1.4)
# Requirement already satisfied: tokenizers>=0.14.0 in /usr/local/lib/python3.12/dist-packages (from voyageai) (0.22.2)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.13 in /usr/local/lib/python3.12/dist-packages (from langchain-text-splitters>=0.3.8->voyageai) (1.2.16)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=1.10.8->voyageai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic>=1.10.8->voyageai) (2.41.4)
# Requirement already satisfied: typing-extensions>=4.14.1 in /usr/local/lib/python3.12/dist-packages (from pydantic>=1.10.8->voyageai) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic>=1.10.8->voyageai) (0.4.2)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in /usr/local/lib/python3.12/dist-packages (from tokenizers>=0.14.0->voyageai) (1.5.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->voyageai) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->voyageai) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->voyageai) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp->voyageai) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp->voyageai) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->voyageai) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->voyageai) (1.22.0)
# Requirement already satisfied: future in /usr/local/lib/python3.12/dist-packages (from ffmpeg-python->voyageai) (1.0.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->voyageai) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->voyageai) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->voyageai) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->voyageai) (2026.2.25)
# Requirement already satisfied: filelock>=3.10.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.14.0->voyageai) (3.24.3)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.14.0->voyageai) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.14.0->voyageai) (1.3.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.14.0->voyageai) (0.28.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.14.0->voyageai) (26.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.14.0->voyageai) (6.0.3)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.14.0->voyageai) (4.67.3)
# Requirement already satisfied: typer in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.14.0->voyageai) (0.24.1)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.13->langchain-text-splitters>=0.3.8->voyageai) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.13->langchain-text-splitters>=0.3.8->voyageai) (0.7.7)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.13->langchain-text-splitters>=0.3.8->voyageai) (0.14.1)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=0.16.4->tokenizers>=0.14.0->voyageai) (4.12.1)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=0.16.4->tokenizers>=0.14.0->voyageai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=0.16.4->tokenizers>=0.14.0->voyageai) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.12/dist-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.13->langchain-text-splitters>=0.3.8->voyageai) (3.0.0)
# Requirement already satisfied: orjson>=3.9.14 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.13->langchain-text-splitters>=0.3.8->voyageai) (3.11.7)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.13->langchain-text-splitters>=0.3.8->voyageai) (1.0.0)
# Requirement already satisfied: xxhash>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.13->langchain-text-splitters>=0.3.8->voyageai) (3.6.0)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.13->langchain-text-splitters>=0.3.8->voyageai) (0.25.0)
# Requirement already satisfied: click>=8.2.1 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0,>=0.16.4->tokenizers>=0.14.0->voyageai) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0,>=0.16.4->tokenizers>=0.14.0->voyageai) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0,>=0.16.4->tokenizers>=0.14.0->voyageai) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0,>=0.16.4->tokenizers>=0.14.0->voyageai) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface-hub<2.0,>=0.16.4->tokenizers>=0.14.0->voyageai) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface-hub<2.0,>=0.16.4->tokenizers>=0.14.0->voyageai) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->huggingface-hub<2.0,>=0.16.4->tokenizers>=0.14.0->voyageai) (0.1.2)
# Downloading voyageai-0.3.7-py3-none-any.whl (34 kB)
# Downloading langchain_text_splitters-1.1.1-py3-none-any.whl (35 kB)
# Downloading aiolimiter-1.2.1-py3-none-any.whl (6.7 kB)
# Downloading ffmpeg_python-0.2.0-py3-none-any.whl (25 kB)
# Installing collected packages: ffmpeg-python, aiolimiter, langchain-text-splitters, voyageai
# Successfully installed aiolimiter-1.2.1 ffmpeg-python-0.2.0 langchain-text-splitters-1.1.1 voyageai-0.3.7

# %%
from pprint import pprint

# %%
#similarity between the phrases
import numpy as np
from typing import List
from rich.console import Console
from rich.table import Table

#returns [-1, +1]

def cosine_similarity(a: List[float], b: List[float]) -> np.float64:
  npa1 = np.array(a)
  npa2 = np.array(b)
  #calculate the cosine of two arrays
  return np.dot(npa1, npa2) / (np.linalg.norm(npa1) * np.linalg.norm(npa2))

# %%
from anthropic import Anthropic
from google.colab import userdata

import voyageai

voyage_api_key = userdata.get('VOYAGEAI_API_KEY')
voyageai_client = voyageai.Client(api_key=voyage_api_key)

api_key = userdata.get('CLAUDEAI_API_KEY')
anthropic_client = Anthropic(api_key=api_key)

# %% [markdown]
# WHAT ARE EMBEDDINGS
#
# A way to represent meaning with numbers
# Text turns into a list of numbers (vector)
# Similar ideas -> similar numbers

# %% [markdown]
# ##Vectors
#
# $$
# \vec(a) = (a_1, a_2, \dots, a_n)
# $$
#
# ## Dot product - скаларно произведение на два вектора
#
# ### Algebraic representation
# $$
# \vec{a} \cdot \vec{b} = \sum_{i=1}^n{a_i b_i}
# $$
#
# ### Geometric representation
#
# $$
# \vec{a} \cdot \vec{b} = \|\vec{a}\| * \|\vec{b}\| * \cos{\theta}
# $$

# %%
phrases = ["cat is on the mat", "it is a beuatiful day", "it is sunny today", "dogs love hotdogs", "math is hard", "math is hard?", "math is soo easy"]

# %%
create_embeddings_response = voyageai_client.embed(
    phrases,
    model="voyage-law-2",
    input_type="document")

# %%
embeddings = [el for el in create_embeddings_response.embeddings]

# %%
console = Console()
table = Table("Phrase 1", "Phrase 2", "Similarity")

for i in range(len(phrases)):
    for j in range(i+1, len(phrases)):
        similarity = cosine_similarity(embeddings[i], embeddings[j])  # ← direct indexing, no .embeddings
        table.add_row(phrases[i], phrases[j], str(round(similarity, 4)))

console.print(table)
# Out:
# ┏━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┓
# ┃ Phrase 1              ┃ Phrase 2              ┃ Similarity ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━┩
# │ cat is on the mat     │ it is a beuatiful day │ 0.3911     │
# │ cat is on the mat     │ it is sunny today     │ 0.3758     │
# │ cat is on the mat     │ dogs love hotdogs     │ 0.4742     │
# │ cat is on the mat     │ math is hard          │ 0.4022     │
# │ cat is on the mat     │ math is hard?         │ 0.3385     │
# │ cat is on the mat     │ math is soo easy      │ 0.3846     │
# │ it is a beuatiful day │ it is sunny today     │ 0.8482     │
# │ it is a beuatiful day │ dogs love hotdogs     │ 0.447      │
# │ it is a beuatiful day │ math is hard          │ 0.4323     │
# │ it is a beuatiful day │ math is hard?         │ 0.4056     │
# │ it is a beuatiful day │ math is soo easy      │ 0.4327     │
# │ it is sunny today     │ dogs love hotdogs     │ 0.4351     │
# │ it is sunny today     │ math is hard          │ 0.396      │
# │ it is sunny today     │ math is hard?         │ 0.3643     │
# │ it is sunny today     │ math is soo easy      │ 0.3858     │
# │ dogs love hotdogs     │ math is hard          │ 0.4035     │
# │ dogs love hotdogs     │ math is hard?         │ 0.376      │
# │ dogs love hotdogs     │ math is soo easy      │ 0.3755     │
# │ math is hard          │ math is hard?         │ 0.9352     │
# │ math is hard          │ math is soo easy      │ 0.9198     │
# │ math is hard?         │ math is soo easy      │ 0.8705     │
# └───────────────────────┴───────────────────────┴────────────┘

# %%
print(embeddings) # всеки embedding е вектор в 1024-мерно пространство
#pprint(embeddings)
# Out:
# [1024, 1024, 1024, 1024, 1024, 1024]
